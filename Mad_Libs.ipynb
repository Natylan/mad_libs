# %% [markdown]
# Mad Libs Generator

# %%
name = input("Enter your name \n")
print("Hello " + name + ", welcome to my Mad Libs\n")

month = input("enter a month: ")
object0 = input("enter an object : ")
vegetable = input("enter a vegetable: ")
food1 = input("enter a food: ")
verb1 = input("enter a verb: ")
animals = input("enter en animal(plural): ")
verb2 = input("enter another verb: ")
space = input("enter a space: ")
love_person = input("enter a love person: ")
object1 = input("enter a object1: ")
food2 = input("enter another food: ")
drink = input("enter a drink: ")
object3 = input("enter a object: \n")

print("""Hola! me llamo {month} y soy {object0}, en las mañanas preparo {vegetable} y {food1}. Luego salgo a {verb1}, me gusta quedarme mirando
a los {animals} {verb2}. \n Cuando vuelvo a {space}, encuentro a {love_person} que me està esperando para comer, tiene la {object1}
preparada con {food2} y {drink}, a veces hasta me sorprende con algun {object3} de postre. Me gusta mucho cuando prepara eso. """.format
(month = month,
object0 = object0,
vegetable = vegetable,
food1 = food1,
verb1 = verb1,
animals = animals, 
verb2 = verb2,
space = space,
love_person = love_person,
object1 = object1,
food2 = food2,
drink = drink,
object3 = object3))

# %%
languagge = input("choose your languagge please: \n (esp / eng)")
if languagge == "eng".lower():

  name = input("Enter your name \n")
  print("Hello " + name + ", welcome to my Mad Libs.\n")

  month = input("enter a month: ")
  object0 = input("enter an object : ")
  vegetable = input("enter a vegetable: ")
  food1 = input("enter a food: ")
  verb1 = input("enter a verb: ")
  animals = input("enter en animal(plural): ")
  verb2 = input("enter another verb: ")
  space = input("enter a space: ")
  love_person = input("enter a love person: ")
  object1 = input("enter a object1: ")
  food2 = input("enter another food: ")
  drink = input("enter a drink: ")
  object3 = input("enter a object: \n")

  print("""Hello! My name is {month} and I am a{object0}. In the morning I prepare {vegetable} and {food1}. Then I go out to {verb1}, I like 
to watch to the {animals} {verb2}. \n When I return to {space}, I find {love_person} who is waiting for me to eat, he has {object1}
made with {food2} and {drink}, sometimes it even surprises me with some {object3} for dessert. I really like it when she prepares that. """.format
(month = month,
object0 = object0,
vegetable = vegetable,
food1 = food1,
verb1 = verb1,
animals = animals, 
verb2 = verb2,
space = space,
love_person = love_person,
object1 = object1,
food2 = food2,
drink = drink,
object3 = object3))
  
elif languagge == "esp".lower():   
  nombre = input("Ingresa tu nombre \n ")
  print ("Hola " + nombre + ", bienvenido a este Mad Libs. \n")

  mes = input ("ingrese un mes :")
  objeto0 = input ("ingrese un objeto :")
  vegetal = input ("ingrese un vegetal :")
  food1 = input ("introduce un alimento :")
  verb1 = input ("ingresa un verbo :")
  animal = input ("ingrese en animal (plural) :")
  verb2 = input ("ingresa otro verbo :")
  espacio = entrada ("ingrese un espacio :")
  persona = input ("ingresa una persona :")
  object1 = input ("ingrese un objeto1 :")
  food2 = input ("introduce otra comida :")
  bebida = input ("ingresa una bebida :")
  object3 = input ("ingrese un objeto : \n")
  print("""Hola! me llamo {month} y soy {object0}. En las mañanas preparo {vegetable} y {food1}. Luego salgo a {verb1}, me gusta quedarme mirando
a los {animals} {verb2}. \n Cuando vuelvo a {space}, encuentro a {love_person} que me està esperando para comer, tiene la {object1}
preparada con {food2} y {drink}, a veces hasta me sorprende con algun {object3} de postre. Me gusta mucho cuando prepara eso. \n""".format
      (mes = mes,
  objeto0 = objeto0,
  vegetal = vegetal,
  comida1 = comida1,
  verbo1 = verbo1,
  animal = animal,
  verbo2 = verbo2,
  espacio = espacio,
  persona = persona,
  objeto1 = objeto1,
  comida2 = comida2,
  bebida = bebida,
  objeto3 = objeto3))
